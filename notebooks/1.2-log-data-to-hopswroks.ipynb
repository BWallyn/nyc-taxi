# %% [markdown]
# # Log data to Hopsworks

# %% [markdown]
# # 1. Imports

# %% [markdown]
# ## 1.1 Packages

# %%
# Data science
import numpy as np
import pandas as pd

# Feature store
import hopsworks

# %% [markdown]
# ## 1.2 Options

# %% [markdown]
# ## 1.3 Dataset

# %%
df_training = pd.read_pickle('../data/05_model_input/df_training.pkl')

# %% [markdown]
# # 2. Log to feature store

# %%
df_training['index'] = np.arange(1, len(df_training) + 1)
df_training
# Out:
#        VendorID tpep_pickup_datetime  passenger_count  trip_distance  \
# 0           2.0  2023-01-01 00:32:10              1.0           0.97
# 1           2.0  2023-01-01 00:55:08              1.0           1.10
# 2           2.0  2023-01-01 00:25:04              1.0           2.51
# 3           1.0  2023-01-01 00:03:48              0.0           1.90
# 4           2.0  2023-01-01 00:10:29              1.0           1.43
# ...         ...                  ...              ...            ...
# 7518        2.0  2023-03-31 16:13:51              1.0           4.36
# 7519        2.0  2023-03-31 16:53:31              1.0           1.09
# 11458       2.0  2023-03-31 16:12:39              1.0           1.84
# 11459       2.0  2023-03-31 16:30:10              1.0           3.29
# 11460       2.0  2023-03-31 16:58:43              1.0           4.30
#
#        RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0             1.0                  N         161.0         141.0
# ...

# %%
hopsworks_project = hopsworks.login(
    host="nyc_taxi_connection", port=8181, api_key_value="DKN8DnyctaxiVKx"
) 
fs = hopsworks_project.get_feature_store()
# Out:
# Connected. Call `.close()` to terminate connection gracefully.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hopsworks_project = hopsworks.login(
#       2     host="nyc_taxi_connection", port=8181, api_key_value="DKN8DnyctaxiVKx"
#       3 )
#       4 fs = hopsworks_project.get_feature_store()
#
# File ~/Git/nyc-taxi/nyc-taxi/lib/python3.11/site-packages/hopsworks/__init__.py:197, in login(host, port, project, api_key_value, api_key_file)
#     194         fh.write(api_key.strip())
#     196 try:
# --> 197     _hw_connection = _hw_connection(host=host, port=port, api_key_value=api_key)
#     198     _connected_project = _prompt_project(_hw_connection, project)
#     199 except RestAPIError as e:
#
# ...

# %%
feature_descriptions = [
    {"name": "vendorid", "description": "Id of the taxi"},
    {"name": "tpep_pickup_datetime", "description": "Pick up time"},
    {"name": "passenger_count", "description": "Number of passenger during the trip"},
    {"name": "trip_distance", "description": "Distance of the trip"},
    {"name": "ratecodeid", "description": "The final rate code in effect at the end of the trip"},
    {"name": "store_and_fwd_flag", "description": "This flag indicates whether the trip record was held in vehicle memory before sending to the vendor, aka store and forward, because the vehicle did not have a connection to the server. "},
    {"name": "pulocationid", "description": "TLC Taxi Zone in which the taximeter was engaged"},
    {"name": "dolocationid", "description": "TLC Taxi Zone in which the taximeter was disengaged"},
    {"name": "payment_type", "description": "A numeric code signifying how the passenger paid for the trip."},
    {"name": "fare_amount", "description": "The time-and-distance fare calculated by the meter."},
    {"name": "extra", "description": "Miscellaneous extras and surcharges.  Currently, this only includes the $0.50 and $1 rush hour and overnight charges."},
    {"name": "mta_tax", "description": "$0.50 MTA tax that is automatically triggered based on the metered rate in use."},
    {"name": "tip_amount", "description": "Tip amount – This field is automatically populated for credit card tips. Cash tips are not included."},
    {"name": "tolls_amount", "description": "Total amount of all tolls paid in trip."},
    {"name": "improvement_surcharge", "description": "$0.30 improvement surcharge assessed trips at the flag drop. The improvement surcharge began being levied in 2015."},
    {"name": "total_amount", "description": "The total amount charged to passengers. Does not include cash tips."},
    {"name": "congestion_surcharge", "description": "Total amount collected in trip for NYS congestion surcharge."},
    {"name": "airport_fee", "description": "$1.25 for pick up only at LaGuardia and John F. Kennedy Airports"},
    {"name": "tpep_pickup_datetime_hour", "description": "Pick up time hour"},
]

# %%
fg_train = fs.get_or_create_feature_group(
    name="nyc_taxi",
    version=2,
    description="Training data for NYC Taxi",
    primary_key=["index"],
    online_enabled=True,
    event_time='tpep_pickup_datetime',
)

# %%
fg_train.insert(df_training)
for desc in feature_descriptions: 
    fg_train.update_feature_description(desc["name"], desc["description"])
# Out:
# ...
# ---------------------------------------------------------------------------
# RestAPIError                              Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 fg_train.insert(df_training)
#       2 for desc in feature_descriptions:
#       3     trans_fg.update_feature_description(desc["name"], desc["description"])
#
# File ~/Git/nyc-taxi/nyc-taxi/lib/python3.11/site-packages/hsfs/feature_group.py:1984, in FeatureGroup.insert(self, features, overwrite, operation, storage, write_options, validation_options, save_code, wait)
#    1981 if "wait_for_job" not in write_options:
#    1982     write_options["wait_for_job"] = wait
# -> 1984 job, ge_report = self._feature_group_engine.insert(
#    1985     self,
#    1986     feature_dataframe=feature_dataframe,
#    1987     overwrite=overwrite,
#    1988     operation=operation,
#    1989     storage=storage.lower() if storage is not None else None,
#    1990     write_options=write_options,
# ...
